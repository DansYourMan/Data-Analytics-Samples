# %%
#Problem 1
import pandas

df_prob1 = pandas.read_csv('/MetObjects_Subset.csv')
df_prob1
# Out:
#           Object Number  Is Highlight  Is Public Domain  Object ID  \
# 0            1979.486.1         False             False          1
# 1            1980.264.5         False             False          2
# 2              67.265.9         False             False          3
# 3             67.265.10         False             False          4
# 4             67.265.11         False             False          5
# ...                 ...           ...               ...        ...
# 17244      2013.959.1.2         False             False      21788
# 17245  2013.959.1.4a, b         False             False      21789
# 17246      2013.959.1.5         False             False      21790
# 17247   2013.959.1.3a–c         False             False      21791
# 17248       2013.959.11         False             False      21792
#
#               Department Object Name                         Title   Culture  \
# 0      The American Wing        Coin  One-dollar Liberty Head Coin       NaN
# ...

# %%
#Problem 2
df_prob2 = df_prob1.copy(deep='True')

# Step 1: Identify NULL columns
null_columns = df_prob2.columns[df_prob2.isnull().all()]

# Step 2: Remove NULL columns
df_prob2 = df_prob2.drop(columns=null_columns)

# Display the cleaned DataFrame
df_prob2
# Out:
#           Object Number  Is Highlight  Is Public Domain  Object ID  \
# 0            1979.486.1         False             False          1
# 1            1980.264.5         False             False          2
# 2              67.265.9         False             False          3
# 3             67.265.10         False             False          4
# 4             67.265.11         False             False          5
# ...                 ...           ...               ...        ...
# 17244      2013.959.1.2         False             False      21788
# 17245  2013.959.1.4a, b         False             False      21789
# 17246      2013.959.1.5         False             False      21790
# 17247   2013.959.1.3a–c         False             False      21791
# 17248       2013.959.11         False             False      21792
#
#               Department Object Name                         Title   Culture  \
# 0      The American Wing        Coin  One-dollar Liberty Head Coin       NaN
# ...

# %%
#Problem 3
#From testing a strict equality will not pass NULL or NaN values
#Does 'Is Public Domain' equal True, ignore everything else
df_prob3 = df_prob2[df_prob2['Is Public Domain'] == True]

df_prob3
# Out:
#         Object Number  Is Highlight  Is Public Domain  Object ID  \
# 33         1970.289.6         False              True         34
# 36          38.165.51         False              True         37
# 37          38.165.50         False              True         38
# 38           18.11.10         False              True         39
# 39         46.140.143         False              True         40
# ...               ...           ...               ...        ...
# 17227        2013.201         False              True      21693
# 17230        2015.437          True              True      21698
# 17236      2013.961.2         False              True      21720
# 17237  2013.961.6a, b         False              True      21728
# 17238        2013.494         False              True      21730
#
#               Department    Object Name  \
# 33     The American Wing          Clock
# 36     The American Wing         Figure
# 37     The American Wing         Figure
# ...

# %%
#Problem 4
#Remove NULL values so the second stage works
df_filterNullRoles = df_prob3.dropna(subset=['Artist Role'])

#Searches the whole string for the 'Maker' substring
df_prob4 = df_filterNullRoles[df_filterNullRoles['Artist Role'].str.contains('Maker')]

df_prob4
# Out:
#         Object Number  Is Highlight  Is Public Domain  Object ID  \
# 33         1970.289.6         False              True         34
# 36          38.165.51         False              True         37
# 37          38.165.50         False              True         38
# 39         46.140.143         False              True         40
# 40         46.140.864         False              True         41
# ...               ...           ...               ...        ...
# 17205        2014.289         False              True      21644
# 17209        2013.113         False              True      21660
# 17210       2013.22.1         False              True      21661
# 17211  2009.226.19a–f         False              True      21667
# 17236      2013.961.2         False              True      21720
#
#               Department          Object Name  \
# 33     The American Wing                Clock
# 36     The American Wing               Figure
# ...

# %%
#Problem 5
import numpy as np

df_prob5 = df_prob4.copy(deep='True')

#Take the data from two other columns and do math
df_prob5['DecadesToMake'] = ((df_prob5['Object End Date'] - df_prob5['Object Begin Date']) / 10).apply(np.floor)

#Used for testing. I verified the math works as expected
#selected_columns = ['Object Begin Date', 'Object End Date', 'DecadesToMake']
#print(df_prob5.loc[:, selected_columns])

df_prob5
# Out:
#         Object Number  Is Highlight  Is Public Domain  Object ID  \
# 33         1970.289.6         False              True         34
# 36          38.165.51         False              True         37
# 37          38.165.50         False              True         38
# 39         46.140.143         False              True         40
# 40         46.140.864         False              True         41
# ...               ...           ...               ...        ...
# 17205        2014.289         False              True      21644
# 17209        2013.113         False              True      21660
# 17210       2013.22.1         False              True      21661
# 17211  2009.226.19a–f         False              True      21667
# 17236      2013.961.2         False              True      21720
#
#               Department          Object Name  \
# 33     The American Wing                Clock
# 36     The American Wing               Figure
# ...

# %%
#Problem 6
import matplotlib.pyplot as plt

# Get the top ten most common classifications
top_classifications = df_prob5['Classification'].value_counts().head(10)

# Plot the bar chart
top_classifications.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('Top Ten Most Common Classifications')
plt.xlabel('Classification')
plt.ylabel('Count')
plt.show()
# Out:
# /.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
